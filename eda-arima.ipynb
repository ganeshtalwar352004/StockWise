# %%
# install pandas reader library
# !pip install yfinance    # provides financial data

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# %% [markdown]
# **Read dataset using  pandas dat reader
# here we are taking yahoo financial data**

# %%
df_tesla = yf.download('TSLA', start='2020-01-01', end='2023-01-01')
df_tesla.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %% [markdown]
# **Volume**: number of stocks traded on that specific day

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
# xlimit and y limit
df_tesla['High'].plot(figsize=(12,4),xlim=['2022-01-01','2023-01-01'])
# Out:
# <Axes: xlabel='Date'>

# %%
# xlimit and y limit we can give limits in tuples also
df_tesla['High'].plot(figsize=(12,4),xlim=['2022-01-01','2023-01-01'],ylim=[0,400],ls='--',c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2022-12-16', '2022-12-19', '2022-12-20', '2022-12-21',
#                '2022-12-22', '2022-12-23', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30'],
#               dtype='datetime64[ns]', name='Date', length=756, freq=None)

# %%
index=df_tesla.loc['2022-01-01':'2022-09-01'].index
share_open=df_tesla.loc['2022-01-01':'2022-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2022-01-03    382.583344
# 2022-01-04    396.516663
# 2022-01-05    382.216675
# 2022-01-06    359.000000
# 2022-01-07    360.123322
#                  ...
# 2022-08-26    297.429993
# 2022-08-29    282.829987
# 2022-08-30    287.869995
# 2022-08-31    280.619995
# 2022-09-01    272.579987
# Name: Open, Length: 168, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#in subplots figure size can't be mentioned
figure,axis=plt.subplots()
plt.tight_layout()    #give son=me padding to plot so that it looks better
figure.autofmt_xdate()   # preventing overlapping 
axis.plot(index,share_open)

# %% [markdown]
# **Date time Index**

# %%
df_tesla=df_tesla.reset_index()    # now date become part of dataframe earlier it was a index
df_tesla
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 1   2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2   2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 3   2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 4   2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ..         ...         ...         ...         ...         ...         ...
# 751 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 752 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 753 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 754 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 755 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#         Volume
# 0    142981500
# 1    266677500
# 2    151995000
# ...

# %%
df_tesla=df_tesla.set_index('Date',drop=True)
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 6, 13, 15, 29, 36, 88763)

# %%
date=datetime(2021,11,21)
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
print(date.date())
print(date.day)
print(date.weekday())
print(date.month)
# Out:
# 2021-11-21
# 21
# 6
# 11

# %% [markdown]
# **time resampling**

# %% [markdown]
# ##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78

# %%
df_tesla.resample(rule='A').min()
#it shows how much each year minimum val was foreach column

# %%
# rule A means year and frequency
#in order to get quartelry we us rule 'QS'
df_tesla.resample(rule='A').max()
# Out:
# /tmp/ipykernel_35/2866018459.py:3: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').max()
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-31  396.516663  402.666656  378.679993  399.926666  399.926666
#
#                Volume
# Date
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-31  221923300

# %%
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# /tmp/ipykernel_35/2734334641.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').max()['Open'].plot()
# <Axes: xlabel='Date'>

# %%
df_tesla.resample(rule='M').max()['Open'].plot(kind='bar',figsize=(15,6))
# Out:
# /tmp/ipykernel_35/634813828.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tesla.resample(rule='M').max()['Open'].plot(kind='bar',figsize=(15,6))
# <Axes: xlabel='Date'>

# %% [markdown]
# # simple moving average or rolling

# %%
# axis==0 ->row        axis==1  ->column
# rolling(0)  we get all nan values
# it takes window size of parameter 2 and give maxi value 
df_tesla['High'].rolling(2).max().head(20)
# Out:
# Date
# 2020-01-02          NaN
# 2020-01-03    30.266666
# 2020-01-06    30.266666
# 2020-01-07    31.441999
# 2020-01-08    33.232666
# 2020-01-09    33.253334
# 2020-01-10    33.253334
# 2020-01-13    35.042000
# 2020-01-14    36.493999
# 2020-01-15    36.493999
# 2020-01-16    35.855999
# 2020-01-17    34.377998
# 2020-01-21    36.571999
# 2020-01-22    39.633331
# 2020-01-23    39.633331
# 2020-01-24    38.799999
# 2020-01-27    38.257332
# 2020-01-28    38.453999
# 2020-01-29    39.320000
# 2020-01-30    43.391998
# Name: High, dtype: float64

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %%
df_tesla['Open :10 days rolling']=df_tesla['Open'].rolling(window=10,min_periods=1).mean()
df_tesla['Open :30 days rolling']=df_tesla['Open'].rolling(window=30,min_periods=1).mean()
df_tesla['Open :50 days rolling']=df_tesla['Open'].rolling(window=50,min_periods=1).mean()

df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500
#
#             Open :10 days rolling  Open :30 days rolling  \
# Date
# 2020-01-02              28.299999              28.299999
# 2020-01-03              28.833333              28.833333
# 2020-01-06              29.010445              29.010445
# 2020-01-07              29.447834              29.447834
# 2020-01-08              29.874267              29.874267
#
#             Open :50 days rolling
# Date
# 2020-01-02              28.299999
# 2020-01-03              28.833333
# ...

# %%
df_tesla[['Open','Open :10 days rolling','Open :30 days rolling','Open :50 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # cumumlativr moving average or expanding

# %%
df_tesla['Open'].expanding().mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # exponential weighted moving average

# %%
df_tesla['EMWA_OPEN']=df_tesla['Open'].ewm(alpha=0.1,adjust=False ).mean()
df_tesla['EMWA_5days']=df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open','Open :10 days rolling','Open :30 days rolling','Open :50 days rolling','EMWA_OPEN','EMWA_5days']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume  Open :10 days rolling  Open :30 days rolling  \
# Date
# ...

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# # Stationarity : ADfuller test

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")
    return result[1]

# %%
p_val=adf_test(df_tesla['Close'])
print(p_val)
# Out:
# ADF Statistics: -1.8775284728871098
# p- value: 0.34270513471141617
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary
# 0.34270513471141617

# %% [markdown]
# # differencing

# %%
c=0
s='Close'
while(p_val>0.05):
    c+=1
    df_tesla[f"Close{c}"]=df_tesla[s]-df_tesla[s].shift(1)
    s=f"Close{c}"
    print(c)
    p_val=adf_test(df_tesla[s].dropna())
print(p_val)
print(c)
# df_tesla
# Out:
# 1
# ADF Statistics: -8.159965585381387
# p- value: 9.200130586253996e-13
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary
# 9.200130586253996e-13
# 1

# %%
acf = plot_acf(df_tesla["Close"].dropna())
acf = plot_pacf(df_tesla["Close"].dropna())

# %%
df_tesla =df_tesla.reset_index()
df_tesla['Date'] = pd.to_datetime(df_tesla['Date'])
df_tesla.set_index('Date', inplace=True)
df_tesla = df_tesla['Close'].to_frame()

# %%
# !pip install pmdarima
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from pmdarima.arima import auto_arima

# Auto ARIMA to select optimal ARIMA parameters
model = auto_arima(df_tesla['Close'], seasonal=False, trace=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5466.466, Time=0.79 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5459.925, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5460.840, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5460.879, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5458.071, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5462.475, Time=0.29 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.373 seconds
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  756
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -2728.036
# Date:                Thu, 13 Jun 2024   AIC                           5458.071
# Time:                        15:29:58   BIC                           5462.698
# Sample:                             0   HQIC                          5459.854
# ...

# %%
df_tesla
# Out:
#                  Close
# Date
# 2020-01-02   28.684000
# 2020-01-03   29.534000
# 2020-01-06   30.102667
# 2020-01-07   31.270666
# 2020-01-08   32.809334
# ...                ...
# 2022-12-23  123.150002
# 2022-12-27  109.099998
# 2022-12-28  112.709999
# 2022-12-29  121.820000
# 2022-12-30  123.180000
#
# [756 rows x 1 columns]

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np

# Define the ARIMA model
def arima_forecast(history):
    # Fit the model
    model = ARIMA(history, order=(0,1,0))
    model_fit = model.fit()
    
    # Make the prediction
    output = model_fit.forecast()
#     print(output.shape)
    yhat = output[0]
    return yhat

# Split data into train and test sets
X = df_tesla.values
size = int(len(X) * 0.8)
# print(len(X))
train, test = X[0:size], X[size:len(X)]

# Walk-forward validation
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    # Generate a prediction
    yhat = arima_forecast(history)
    predictions.append(yhat)
    # Add the predicted value to the training set
    obs = test[t]
    history.append(obs)

# %%
import matplotlib.pyplot as plt

print(df_tesla.iloc[size:,:].index)
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(df_tesla.iloc[size:,:].index, test, label='Real')
plt.plot(df_tesla.iloc[size:,:].index, predictions, color='red', label='Predicted')
plt.title('ARIMA Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# DatetimeIndex(['2022-05-25', '2022-05-26', '2022-05-27', '2022-05-31',
#                '2022-06-01', '2022-06-02', '2022-06-03', '2022-06-06',
#                '2022-06-07', '2022-06-08',
#                ...
#                '2022-12-16', '2022-12-19', '2022-12-20', '2022-12-21',
#                '2022-12-22', '2022-12-23', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30'],
#               dtype='datetime64[ns]', name='Date', length=152, freq=None)
